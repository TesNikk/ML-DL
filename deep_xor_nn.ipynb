# %% [markdown]
# <a href="https://colab.research.google.com/github/TesNikk/ML-DL/blob/main/deep_xor_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Prepare training data
training_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]], dtype="float32")
target_data = np.array([[0], [1], [1], [0]], dtype="float32")

# Create the model
model = Sequential([
    Dense(16, input_shape=(2,), activation='relu'),
    Dense(16, activation='relu'),
    Dense(16, activation='relu'),
    Dense(16, activation='relu'),
    Dense(16, activation='relu'),
    Dense(16, activation='relu'),
    Dense(16, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy'])

# Train the model
model.fit(training_data, target_data, epochs=300, verbose=2)

# Make predictions
predictions = model.predict(training_data).round()
print("Predictions:")
print(predictions)
# Out:
# Epoch 1/300
# 1/1 - 3s - 3s/step - binary_accuracy: 0.5000 - loss: 0.2501
# Epoch 2/300
# 1/1 - 0s - 44ms/step - binary_accuracy: 0.5000 - loss: 0.2495
# Epoch 3/300
# 1/1 - 0s - 59ms/step - binary_accuracy: 0.7500 - loss: 0.2490
# Epoch 4/300
# 1/1 - 0s - 42ms/step - binary_accuracy: 0.7500 - loss: 0.2487
# Epoch 5/300
# 1/1 - 0s - 45ms/step - binary_accuracy: 0.7500 - loss: 0.2485
# Epoch 6/300
# 1/1 - 0s - 58ms/step - binary_accuracy: 0.7500 - loss: 0.2483
# Epoch 7/300
# 1/1 - 0s - 45ms/step - binary_accuracy: 0.7500 - loss: 0.2480
# Epoch 8/300
# 1/1 - 0s - 64ms/step - binary_accuracy: 0.7500 - loss: 0.2478
# Epoch 9/300
# 1/1 - 0s - 47ms/step - binary_accuracy: 0.7500 - loss: 0.2475
# Epoch 10/300
# 1/1 - 0s - 58ms/step - binary_accuracy: 0.7500 - loss: 0.2472
# Epoch 11/300
# 1/1 - 0s - 59ms/step - binary_accuracy: 0.7500 - loss: 0.2469
# Epoch 12/300
# 1/1 - 0s - 59ms/step - binary_accuracy: 0.7500 - loss: 0.2466
# Epoch 13/300
# ...
